# %%
import numpy as np
import matplotlib.pyplot as plt

# x range
x = np.linspace(-15, 5, 500)

plt.figure(0, figsize=(8, 8))

# Shaded regions
plt.fill_between(x, x - 2, x + 2, color='grey', alpha=0.3, label=r'$y = x \pm 2$')
plt.fill_between(x, x - 1, x + 1, color='grey', alpha=0.6, label=r'$y = x \pm 1$')

# Diagonal y = x
plt.plot(x, x, color='black', linestyle='--', label=r'$y = x$')

# Whole graph base (raw)
expt_edge_data = np.array([-0.272, -0.643, -1.57, -1.448, -1.391, -3.072, -0.371, -1.298, -1.176, -1.119, -2.8, -0.927, 0.057, 1.489, 0.805, -1.624, 1.432, 0.748, -1.681, -0.684])
UFE_edge_data = np.array([-1.312, -2.102, 0.725, -4.856, -0.533, -18.058, 0.249, -0.621, -4.837, 2.1, -15.933, 0.46, -0.841, 0.214, -0.193, -12.053, 0.572, 0.342, -17.9, 0.57])
UFE_edge_data_err = np.array([0.07, 0.138, 0.121, 0.267, 0.225, 0.183, 0.089, 0.174, 0.299, 0.292, 0.251, 0.204, 0.051, 0.017, 0.05, 0.141, 0.071, 0.042, 0.125, 0.069])

CFE_edge_data = np.array([-0.991, -1.271, -0.486, -2.727, -2.77, -17.517, -0.28, 0.505, -1.736, -1.778, -16.526, 0.785, -0.043, 0.021, 0.116, -14.79, 0.064, 0.159, -14.747, 0.095])
CFE_edge_data_err = np.array([0.097, 0.118, 0.121, 0.089, 0.091, 0.106, 0.121, 0.124, 0.093, 0.095, 0.109, 0.141, 0.087, 0.086, 0.09, 0.103, 0.088, 0.092, 0.104, 0.091])


plt.errorbar(expt_edge_data, UFE_edge_data, yerr=UFE_edge_data_err, fmt='o', color='red', ecolor='red',
             elinewidth=1.5, capsize=5, label='UFE Edge Data')

coeffs_UFE = np.polyfit(expt_edge_data, UFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_UFE = np.poly1d(coeffs_UFE)

# Plot the fitted trendline
plt.plot(x, fit_line_UFE(x), color='red', linestyle='--', linewidth=2)


plt.errorbar(expt_edge_data, CFE_edge_data, yerr=CFE_edge_data_err, fmt='o', color='blue', ecolor='blue',
             elinewidth=1.5, capsize=5, label='CFE Edge Data')

coeffs_CFE = np.polyfit(expt_edge_data, CFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_CFE = np.poly1d(coeffs_CFE)

# Plot the fitted trendline
plt.plot(x, fit_line_CFE(x), color='blue', linestyle='--', linewidth=2)

# Axis settings
plt.xlabel(r'$\Delta\Delta$$G_{exp}$ (kcal/mol)',fontsize=16)
plt.ylabel(r'$\Delta\Delta$$G_{cal}$ (kcal/mol)',fontsize=16)
plt.xlim(-15, 5)
plt.ylim(-20, 5)
plt.legend()
plt.grid(True)
plt.title('Whole graph (base)')
#plt.axis('equal')
plt.show()

# %%
plt.figure(1, figsize=(8, 8))

# Shaded regions
plt.fill_between(x, x - 2, x + 2, color='grey', alpha=0.3, label=r'$y = x \pm 2$')
plt.fill_between(x, x - 1, x + 1, color='grey', alpha=0.6, label=r'$y = x \pm 1$')

# Diagonal y = x
plt.plot(x, x, color='black', linestyle='--', label=r'$y = x$')

# Whole graph larger CMC sc
expt_edge_data = np.array([-0.272, -0.643, -1.57, -1.448, -1.391, -3.072, -0.371, -1.298, -1.176, -1.119, -2.8, -0.927, 0.057, 1.489, 0.805, -1.624, 1.432, 0.748, -1.681, -0.684])
UFE_edge_data = np.array([-1.308, -2.04, 0.589, -4.856, -0.533, -18.058, -0.316, -0.525, -4.837, 2.1, -15.933, 0.89, -0.841, 0.214, -0.193, -12.053, 0.572, 0.342, -17.9, 0.57])
UFE_edge_data_err = np.array([0.073, 0.136, 0.095, 0.267, 0.225, 0.183, 0.067, 0.117, 0.299, 0.292, 0.251, 0.104, 0.051, 0.017, 0.05, 0.141, 0.071, 0.042, 0.125, 0.069])

CFE_edge_data = np.array([-0.931, -1.548, -0.457, -2.698, -2.741, -17.488, -0.616, 0.475, -1.767, -1.809, -16.557, 1.091, -0.043, 0.021, 0.116, -14.79, 0.064, 0.159, -14.748, 0.095])
CFE_edge_data_err = np.array([0.104, 0.111, 0.111, 0.096, 0.096, 0.117, 0.113, 0.113, 0.098, 0.099, 0.118, 0.119, 0.09, 0.091, 0.093, 0.111, 0.091, 0.094, 0.112, 0.094])


plt.errorbar(expt_edge_data, UFE_edge_data, yerr=UFE_edge_data_err, fmt='o', color='red', ecolor='red',
             elinewidth=1.5, capsize=5, label='UFE Edge Data')

coeffs_UFE = np.polyfit(expt_edge_data, UFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_UFE = np.poly1d(coeffs_UFE)

# Plot the fitted trendline
plt.plot(x, fit_line_UFE(x), color='red', linestyle='--', linewidth=2)


plt.errorbar(expt_edge_data, CFE_edge_data, yerr=CFE_edge_data_err, fmt='o', color='blue', ecolor='blue',
             elinewidth=1.5, capsize=5, label='CFE Edge Data')

coeffs_CFE = np.polyfit(expt_edge_data, CFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_CFE = np.poly1d(coeffs_CFE)

# Plot the fitted trendline
plt.plot(x, fit_line_CFE(x), color='blue', linestyle='--', linewidth=2)


# Axis settings
plt.xlabel(r'$\Delta\Delta$$G_{exp}$ (kcal/mol)',fontsize=16)
plt.ylabel(r'$\Delta\Delta$$G_{cal}$ (kcal/mol)',fontsize=16)
plt.xlim(-15, 5)
plt.ylim(-20, 5)
plt.legend()
plt.grid(True)
plt.title('Whole graph (larger CMC sc)')
#plt.axis('equal')
plt.show()

# %%
plt.figure(2, figsize=(8, 8))

# Shaded regions
plt.fill_between(x, x - 2, x + 2, color='grey', alpha=0.3, label=r'$y = x \pm 2$')
plt.fill_between(x, x - 1, x + 1, color='grey', alpha=0.6, label=r'$y = x \pm 1$')

# Diagonal y = x
plt.plot(x, x, color='black', linestyle='--', label=r'$y = x$')

# Whole graph CMC intermediates
expt_edge_data = np.array([-0.272, -0.643, -1.57, -1.448, -1.391, -3.072, -0.371, -1.298, -1.176, -1.119, -2.8, -0.927, 0.057, 1.489, 0.805, -1.624, 1.432, 0.748, -1.681, -0.684])
UFE_edge_data = np.array([-1.312, -2.102, 0.7, -4.856, -0.533, -18.058, 0.249, 2, -4.837, 2.1, -15.933, 2.307, -0.841, 0.214, -0.193, -12.053, 0.572, 0.342, -17.9, 0.57])
UFE_edge_data_err = np.array([0.07, 0.138, 0.072, 0.267, 0.225, 0.183, 0.089, 0.111, 0.299, 0.292, 0.251, 0.147, 0.051, 0.017, 0.05, 0.141, 0.071, 0.042, 0.125, 0.069])

CFE_edge_data = np.array([-1.531, -1.7, 0.596, -2.987, -3.03, -17.777, -0.169, 2.127, -1.456, -1.499, -16.246, 2.296, -0.043, 0.021, 0.116, -14.789, 0.064, 0.159, -14.747, 0.095])
CFE_edge_data_err = np.array([0.103, 0.113, 0.107, 0.095, 0.095, 0.101, 0.118, 0.113, 0.101, 0.101, 0.107, 0.122, 0.093, 0.093, 0.096, 0.099, 0.093, 0.096, 0.099, 0.097])


plt.errorbar(expt_edge_data, UFE_edge_data, yerr=UFE_edge_data_err, fmt='o', color='red', ecolor='red',
             elinewidth=1.5, capsize=5, label='UFE Edge Data')
coeffs_UFE = np.polyfit(expt_edge_data, UFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_UFE = np.poly1d(coeffs_UFE)

# Plot the fitted trendline
plt.plot(x, fit_line_UFE(x), color='red', linestyle='--', linewidth=2)


plt.errorbar(expt_edge_data, CFE_edge_data, yerr=CFE_edge_data_err, fmt='o', color='blue', ecolor='blue',
             elinewidth=1.5, capsize=5, label='CFE Edge Data')

coeffs_CFE = np.polyfit(expt_edge_data, CFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_CFE = np.poly1d(coeffs_CFE)

# Plot the fitted trendline
plt.plot(x, fit_line_CFE(x), color='blue', linestyle='--', linewidth=2)

# Axis settings
plt.xlabel(r'$\Delta\Delta$$G_{exp}$ (kcal/mol)',fontsize=16)
plt.ylabel(r'$\Delta\Delta$$G_{cal}$ (kcal/mol)',fontsize=16)
plt.xlim(-15, 5)
plt.ylim(-20, 5)
plt.legend()
plt.grid(True)
plt.title('Whole graph (CMC intermediates)')
#plt.axis('equal')
plt.show()

# %%
plt.figure(3, figsize=(8, 8))

# Shaded regions
plt.fill_between(x, x - 2, x + 2, color='grey', alpha=0.3, label=r'$y = x \pm 2$')
plt.fill_between(x, x - 1, x + 1, color='grey', alpha=0.6, label=r'$y = x \pm 1$')

# Diagonal y = x
plt.plot(x, x, color='black', linestyle='--', label=r'$y = x$')

# Whole graph CMC intermediates
expt_edge_data = np.array([-0.272, -0.643, -1.57, -1.448, -1.391, -0.371, -1.298, -1.176, -1.119,  -0.927, 0.057, 1.489, 0.805, 1.432, 0.748, -0.684])
UFE_edge_data = np.array([-1.312, -2.102, 0.7, -4.856, -0.533, 0.249, 2, -4.837, 2.1,  2.307, -0.841, 0.214, -0.193, 0.572, 0.342, 0.57])
UFE_edge_data_err = np.array([0.07, 0.138, 0.072, 0.267, 0.225, 0.089, 0.111, 0.299, 0.292, 0.147, 0.051, 0.017, 0.05, 0.071, 0.042, 0.069])

CFE_edge_data = np.array([-1.531, -1.7, 0.596, -2.987, -3.03,  -0.169, 2.127, -1.456, -1.499,  2.296, -0.043, 0.021, 0.116,  0.064, 0.159, 0.095])
CFE_edge_data_err = np.array([0.103, 0.113, 0.107, 0.095, 0.095,  0.118, 0.113, 0.101, 0.101,  0.122, 0.093, 0.093, 0.096,  0.093, 0.096,  0.097])


plt.errorbar(expt_edge_data, UFE_edge_data, yerr=UFE_edge_data_err, fmt='o', color='red', ecolor='red',
             elinewidth=1.5, capsize=5, label='UFE Edge Data')
coeffs_UFE = np.polyfit(expt_edge_data, UFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_UFE = np.poly1d(coeffs_UFE)

# Plot the fitted trendline
plt.plot(x, fit_line_UFE(x), color='red', linestyle='--', linewidth=2)


plt.errorbar(expt_edge_data, CFE_edge_data, yerr=CFE_edge_data_err, fmt='o', color='blue', ecolor='blue',
             elinewidth=1.5, capsize=5, label='CFE Edge Data')

coeffs_CFE = np.polyfit(expt_edge_data, CFE_edge_data, 1)  # Linear fit (degree 1)
fit_line_CFE = np.poly1d(coeffs_CFE)

# Plot the fitted trendline
plt.plot(x, fit_line_CFE(x), color='blue', linestyle='--', linewidth=2)

# Axis settings
plt.xlabel(r'$\Delta\Delta$$G_{exp}$ (kcal/mol)',fontsize=16)
plt.ylabel(r'$\Delta\Delta$$G_{cal}$ (kcal/mol)',fontsize=16)
plt.xlim(-15, 5)
plt.ylim(-20, 5)
plt.legend()
plt.grid(True)
plt.title('Whole graph (CMC intermediates without orita_13)')
#plt.axis('equal')
plt.show()
